# %%
import glob
import json

bronze_badge = {}
silver_badge = {}
gold_badge = {}

for filename in glob.glob(r"badges\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        
        for item in P["items"]:
            #print(item)
            #print(item["rank"])
            if item["rank"] == "bronze":
                #print(item["rank"])
                bronze_badge[item["name"]] = item["award_count"]
                #print(item["name"])
                #print(item["award_count"])
            elif item["rank"] == "silver":
                silver_badge[item["name"]] = item["award_count"]
            elif item["rank"] == "gold":
                gold_badge[item["name"]] = item["award_count"]
                    
                    
#print(bronze_badge)
#print(silver_badge)
#print(gold_badge)

#bronze_badge_sorted = sorted(bronze_badge, key=bronze_badge.get, reverse=True)
#silver_badge_sorted = sorted(silver_badge, key=silver_badge.get, reverse=True)
#gold_badge_sorted = sorted(gold_badge, key=gold_badge.get, reverse=True)

import operator
bronze_badge_sorted = sorted(bronze_badge.items(), key=operator.itemgetter(1), reverse = True)
silver_badge_sorted = sorted(silver_badge.items(), key=operator.itemgetter(1), reverse = True)
gold_badge_sorted = sorted(gold_badge.items(), key=operator.itemgetter(1), reverse = True)

import pyexcel

pyexcel.save_as(array = bronze_badge_sorted, dest_file_name = r'badges\BronzeBadgesSorted.csv')
pyexcel.save_as(array = silver_badge_sorted, dest_file_name = r'badges\SilverBadgesSorted.csv')
pyexcel.save_as(array = gold_badge_sorted, dest_file_name = r'badges\GoldBadgesSorted.csv')

#print(bronze_badge)

#print(bronze_badge_sorted)

# %%
import glob
import json
import requests
import operator
import time

tag_count = {}

#Finding the most popular tag

for filename in glob.glob(r"tags\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        
        try:
            for item in P["items"]:
                tag_count[item["name"]] = item["count"]
        except KeyError:
            print("Skipping a file...")
tag_name_sorted = sorted(tag_count, key=tag_count.get, reverse=True)

tag_value_sorted = sorted(tag_count.items(), key=operator.itemgetter(1), reverse = True)

print("Top two tags of all times are {val}".format(val = tag_name_sorted[:2]))

import pyexcel
pyexcel.save_as(array = tag_value_sorted, dest_file_name = r'tags\TagsSorted.csv')

#Getting top 3 questions for each of the three tags

i = 0;

while i < 2:

    searchUrl = "https://api.stackexchange.com/2.2/tags/"+tag_name_sorted[i]+"/faq?key=QfgSYwzvIpLIqngtwggFPg((&site=stackoverflow"
    r = requests.get(searchUrl, stream = True)

    #print(r.content)
    rec = dict(r.json())
    
    #print(rec)
    
    question_value = {}
    
    json.dumps(rec)
    #print(rec)
    filename = 'tags\\'+tag_name_sorted[i]+'.json'
    with open(filename ,'w')as f:
        json.dump(rec, f)
        
    with open(filename, 'r') as f:
        P = json.load(f)

    try:
        for item in P["items"]:
            impact_factor = item["view_count"] + item["score"]/2
            question_value[item["title"]] = impact_factor
    except KeyError:
        print("")
    
    question_sorted = sorted(question_value.items(), key=operator.itemgetter(1), reverse = True)
    
    import pyexcel

    pyexcel.save_as(array = question_sorted, dest_file_name = 'tags\\'+tag_name_sorted[i]+'.csv')
        
    i += 1
    
    #time.sleep(15)

#print (rec)

#print(tag_name_sorted)
# Out:
# Skipping a file...
# Skipping a file...
# Skipping a file...
# Top two tags of all times are ['javascript', 'java']
# {'has_more': True, 'quota_max': 10000, 'items': [{'view_count': 665435, 'last_edit_date': 1473444759, 'creation_date': 1357664774, 'link': 'http://stackoverflow.com/questions/14220321/how-do-i-return-the-response-from-an-asynchronous-call', 'answer_count': 17, 'accepted_answer_id': 14220323, 'title': 'How do I return the response from an asynchronous call?', 'protected_date': 1369947479, 'owner': {'profile_image': 'https://i.stack.imgur.com/4P5DY.jpg?s=128&g=1', 'user_id': 218196, 'accept_rate': 100, 'link': 'http://stackoverflow.com/users/218196/felix-kling', 'display_name': 'Felix Kling', 'reputation': 395766, 'user_type': 'registered'}, 'score': 2436, 'last_activity_date': 1477622034, 'tags': ['javascript', 'jquery', 'ajax', 'asynchronous'], 'question_id': 14220321, 'is_answered': True}, {'view_count': 175983, 'last_edit_date': 1450698679, 'creation_date': 1239775580, 'link': 'http://stackoverflow.com/questions/750486/javascript-closure-inside-loops-simple-practical-example', 'answer_count': 23, 'accepted_answer_id': 750506, 'title': 'JavaScript closure inside loops – simple practical example', 'protected_date': 1399777873, 'owner': {'profile_image': 'https://www.gravatar.com/avatar/0a6d284d4e2ce68e1c60871858da800b?s=128&d=identicon&r=PG', 'user_id': 9021, 'accept_rate': 71, 'link': 'http://stackoverflow.com/users/9021/nickf', 'display_name': 'nickf', 'reputation': 287768, 'user_type': 'registered'}, 'score': 1488, 'last_activity_date': 1471337282, 'tags': ['javascript', 'loops', 'closures'], 'question_id': 750486, 'is_answered': True}, {'view_count': 415915, 'last_edit_date': 1446602179, 'creation_date': 1224026719, 'link': 'http://stackoverflow.com/questions/203198/event-binding-on-dynamically-created-elements', 'answer_count': 15, 'accepted_answer_id': 1207393, 'title': 'Event binding on dynamically created elements?', 'protected_date': 1395655750, 'owner': {'profile_image': 'https://www.gravatar.com/avatar/f198305bbd04f5fd7c49051dd6e77782?s=128&d=identicon&r=PG', 'user_id': 27580, 'accept_rate': 79, 'link': 'http://stackoverflow.com/users/27580/eli', 'display_name': 'Eli', 'reputation': 36118, 'user_type': 'registered'}, 'score': 1002, 'last_activity_date': 1472208306, 'tags': ['javascript', 'jquery', 'events', 'unobtrusive-javascript'], 'question_id': 203198, 'is_answered': True}, {'view_count': 2240920, 'last_edit_date': 1428368108, 'creation_date': 1243066248, 'link': 'http://stackoverflow.com/questions/901115/how-can-i-get-query-string-values-in-javascript', 'answer_count': 73, 'accepted_answer_id': 901144, 'title': 'How can I get query string values in JavaScript?', 'protected_date': 1319383651, 'owner': {'profile_image': 'https://i.stack.imgur.com/LpKk1.jpg?s=128&g=1', 'user_id': 49742, 'accept_rate': 65, 'link': 'http://stackoverflow.com/users/49742/kemal-emin', 'display_name': 'Kemal Emin', 'reputation': 6154, 'user_type': 'registered'}, 'locked_date': 1406316939, 'community_owned_date': 1343334545, 'score': 2706, 'last_activity_date': 1477063953, 'tags': ['javascript', 'url', 'plugins', 'query-string'], 'question_id': 901115, 'is_answered': True}, {'view_count': 895704, 'last_edit_date': 1469643802, 'creation_date': 1222006327, 'link': 'http://stackoverflow.com/questions/111102/how-do-javascript-closures-work', 'answer_count': 82, 'accepted_answer_id': 111111, 'title': 'How do JavaScript closures work?', 'protected_date': 1316450131, 'owner': {'profile_image': 'https://www.gravatar.com/avatar/1449ec95d8c114dbca53136cc8194b61?s=128&d=identicon&r=PG&f=1', 'user_id': 9951, 'accept_rate': 79, 'link': 'http://stackoverflow.com/users/9951/e-satis', 'display_name': 'e-satis', 'reputation': 252987, 'user_type': 'registered'}, 'community_owned_date': 1370514175, 'score': 6618, 'last_activity_date': 1477469359, 'tags': ['javascript', 'scope', 'closures'], 'question_id': 111102, 'is_answered': True}, {'view_count': 79659, 'last_edit_date': 1427767078, 'creation_date': 1385705591, 'link': 'http://stackoverflow.com/question ...
# {'has_more': True, 'quota_max': 10000, 'items': [{'view_count': 1073370, 'last_edit_date': 1464279301, 'creation_date': 1224508689, 'link': 'http://stackoverflow.com/questions/218384/what-is-a-nullpointerexception-and-how-do-i-fix-it', 'answer_count': 12, 'accepted_answer_id': 218510, 'title': 'What is a NullPointerException, and how do I fix it?', 'owner': {'profile_image': 'https://www.gravatar.com/avatar/af3daf5de4ebd0531d978fad803a46a0?s=128&d=identicon&r=PG', 'user_id': 29182, 'accept_rate': 93, 'link': 'http://stackoverflow.com/users/29182/ziggy', 'display_name': 'Ziggy', 'reputation': 7424, 'user_type': 'registered'}, 'locked_date': 1409094259, 'score': 211, 'last_activity_date': 1476288863, 'tags': ['java', 'nullpointerexception'], 'question_id': 218384, 'is_answered': True}, {'view_count': 2009525, 'last_edit_date': 1358948167, 'creation_date': 1233789427, 'link': 'http://stackoverflow.com/questions/513832/how-do-i-compare-strings-in-java', 'answer_count': 23, 'accepted_answer_id': 513839, 'title': 'How do I compare strings in Java?', 'protected_date': 1391145623, 'owner': {'profile_image': 'https://www.gravatar.com/avatar/b02cab91fb3c5604163c116c494de2a5?s=128&d=identicon&r=PG', 'user_id': 25645, 'accept_rate': 69, 'link': 'http://stackoverflow.com/users/25645/nathan-h', 'display_name': 'Nathan H', 'reputation': 15525, 'user_type': 'registered'}, 'locked_date': 1390766401, 'community_owned_date': 1387280770, 'score': 727, 'last_activity_date': 1473422123, 'tags': ['java', 'string', 'equality'], 'question_id': 513832, 'is_answered': True}, {'view_count': 1107570, 'last_edit_date': 1462618043, 'creation_date': 1220386469, 'link': 'http://stackoverflow.com/questions/40480/is-java-pass-by-reference-or-pass-by-value', 'answer_count': 69, 'title': 'Is Java &quot;pass-by-reference&quot; or &quot;pass-by-value&quot;?', 'protected_date': 1308938923, 'owner': {'reputation': 2275, 'user_id': 4315, 'user_type': 'registered', 'link': 'http://stackoverflow.com/users/4315/user4315', 'display_name': 'user4315'}, 'community_owned_date': 1347646975, 'score': 3654, 'last_activity_date': 1476896604, 'tags': ['java', 'methods', 'parameter-passing', 'pass-by-reference', 'pass-by-value'], 'question_id': 40480, 'is_answered': True}, {'view_count': 74188, 'last_edit_date': 1460367666, 'creation_date': 1330862020, 'link': 'http://stackoverflow.com/questions/9554636/the-use-of-multiple-jframes-good-or-bad-practice', 'answer_count': 9, 'accepted_answer_id': 9554657, 'title': 'The Use of Multiple JFrames: Good or Bad Practice?', 'protected_date': 1374566916, 'owner': {'profile_image': 'https://www.gravatar.com/avatar/020340a72dfea67df7c4ead460b56c9d?s=128&d=identicon&r=PG', 'user_id': 1198226, 'accept_rate': 87, 'link': 'http://stackoverflow.com/users/1198226/peddler', 'display_name': 'Peddler', 'reputation': 1970, 'user_type': 'registered'}, 'score': 358, 'closed_reason': 'primarily opinion-based', 'last_activity_date': 1460367666, 'tags': ['java', 'swing', 'user-interface', 'jframe'], 'question_id': 9554636, 'closed_date': 1419868266, 'is_answered': True}, {'view_count': 195297, 'last_edit_date': 1440778660, 'creation_date': 1278314646, 'link': 'http://stackoverflow.com/questions/3177733/how-to-avoid-java-code-in-jsp-files', 'answer_count': 25, 'accepted_answer_id': 3180202, 'title': 'How to avoid Java code in JSP files?', 'protected_date': 1310383056, 'owner': {'profile_image': 'https://www.gravatar.com/avatar/043703d9aa973023306d6562404804b7?s=128&d=identicon&r=PG', 'user_id': 95914, 'accept_rate': 87, 'link': 'http://stackoverflow.com/users/95914/former', 'display_name': 'former', 'reputation': 6462, 'user_type': 'registered'}, 'score': 1211, 'last_activity_date': 1475777599, 'tags': ['java', 'jsp', 'scriptlet'], 'question_id': 3177733, 'is_answered': True}, {'view_count': 32853, 'last_edit_date': 1404070367, 'creation_date': 1314615751, 'link': 'http://stackoverflow.com/questions/7229226/should-i-avoid-the-use-of-setpreferredmaximumminimum ...

# %%
import glob
import json
import requests
import operator
import time

#Seggregating data according to time

python_trend = {2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
java_trend = {2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}

for filename in glob.glob(r"questions\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        
        try:
            for item in P["items"]:
                
                #year 2008
                
                if (item["creation_date"] > 1199145600 and item["creation_date"] < 1230767999):
                    if "python" in item["tags"]:
                        python_trend[2008] += 1
                    elif "java" in item["tags"]:
                        java_trend[2008] += 1
                        
                #year 2009
                
                elif (item["creation_date"] > 1230768000 and item["creation_date"] < 1262303999):
                    if "python" in item["tags"]:
                        python_trend[2009] += 1
                    elif "java" in item["tags"]:
                        java_trend[2009] += 1
                        
                #year 2010
                
                elif (item["creation_date"] > 1262304000 and item["creation_date"] < 1293839999):
                    if "python" in item["tags"]:
                        python_trend[2010] += 1
                    elif "java" in item["tags"]:
                        java_trend[2010] += 1
                        
                #year 2011
                
                elif (item["creation_date"] > 1293840000 and item["creation_date"] < 1325375999):
                    #print("here")
                    if "python" in item["tags"]:
                        python_trend[2011] += 1
                    elif "java" in item["tags"]:
                        java_trend[2011] += 1
                        
                #year 2012
                
                elif (item["creation_date"] > 1325376000 and item["creation_date"] < 1356998399):
                    #print("here")
                    if "python" in item["tags"]:
                        python_trend[2012] += 1
                    elif "java" in item["tags"]:
                        java_trend[2012] += 1
                        
                #year 2013
                
                elif (item["creation_date"] > 1356998400 and item["creation_date"] < 1388534399):
                    if "python" in item["tags"]:
                        python_trend[2013] += 1
                    elif "java" in item["tags"]:
                        java_trend[2013] += 1
                        
                #year 2014
                
                elif (item["creation_date"] > 1388534400 and item["creation_date"] < 1420070399):
                    if "python" in item["tags"]:
                        python_trend[2014] += 1
                    elif "java" in item["tags"]:
                        java_trend[2014] += 1
                        
                #year 2015
                
                elif (item["creation_date"] > 1420070400 and item["creation_date"] < 1451606399):
                    if "python" in item["tags"]:
                        python_trend[2015] += 1
                    elif "java" in item["tags"]:
                        java_trend[2015] += 1
                        
                #year 2016
                
                elif (item["creation_date"] > 1451606400 and item["creation_date"] < 1483228799):
                    if "python" in item["tags"]:
                        python_trend[2016] += 1
                    elif "java" in item["tags"]:
                        java_trend[2016] += 1
        except KeyError:
            print("")
            
        #time.sleep(0.2)
            
print(python_trend)
print(java_trend)

dicts = python_trend, java_trend

import csv

with open(r'questions\trend.csv', 'w') as ofile:
    writer = csv.writer(ofile, delimiter='\t')
    writer.writerow(['Year', 'python_trend', 'java_trend'])
    for key in python_trend.keys():
        writer.writerow([key] + [d[key] for d in dicts])
# Out:
# {2016: 20, 2008: 166, 2009: 223, 2010: 145, 2011: 362, 2012: 236, 2013: 114, 2014: 32, 2015: 28}
# {2016: 12, 2008: 172, 2009: 248, 2010: 194, 2011: 488, 2012: 249, 2013: 184, 2014: 107, 2015: 45}

# %%
import glob
import json
import requests
import operator
import time

question_value_python = {}
count_python = 0
question_value_java = {}
count_java = 0

for filename in glob.glob(r"unansweredQuestions\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        
        try:
            for item in P["items"]:
                if "python" in item["tags"]:
                    impact_factor = item["view_count"] + item["score"]
                    question_value_python[item["title"]] = impact_factor
                    count_python += 1
                elif "java" in item["tags"]:
                    impact_factor = item["view_count"] + item["score"]
                    question_value_java[item["title"]] = impact_factor
                    count_java += 1
        except KeyError:
            print("")
            
            
import operator
python_questions_sorted = sorted(question_value_python.items(), key=operator.itemgetter(1), reverse = True)
java_questions_sorted = sorted(question_value_java.items(), key=operator.itemgetter(1), reverse = True)
                
#print(count_python)
#print(count_java)

if(count_python > count_java):
    print("Python has more number of unanswered questions than Java")
elif(count_java > count_python):
    print("Java has more number of unanswered questions than Python")
else:
    print("It's difficult to tell at this point which has more number of unanswered questions")

top_three_python = sorted(question_value_python, key=question_value_python.get, reverse=True)[0:3]

print("\nTop three most popular unanswered questions under 'Python' tag are:")
print("1. {val}".format(val = top_three_python[0]))
print("2. {val}".format(val = top_three_python[1]))
print("3. {val}".format(val = top_three_python[2]))

top_three_java = sorted(question_value_java, key=question_value_java.get, reverse=True)[0:3]

print("\nTop three most popular unanswered questions under 'Java' tag are:")
print("1. {val}".format(val = top_three_java[0]))
print("2. {val}".format(val = top_three_java[1]))
print("3. {val}".format(val = top_three_java[2]))

print("\nPlease open .csv file for more detailed summary")

import pyexcel
pyexcel.save_as(array = python_questions_sorted, dest_file_name = r'unansweredQuestions\pythonUnansweredSorted.csv')
pyexcel.save_as(array = java_questions_sorted, dest_file_name = r'unansweredQuestions\javaUnansweredSorted.csv')
# Out:
# Java has more number of unanswered questions than Python
#
# Top three most popular unanswered questions under 'Python' tag are:
# 1. apache2 and mod wsgi : Target WSGI script cannot be loaded as Python module
# 2. numpy array 1.9.2 getting ValueError: could not broadcast input array from shape (4,2) into shape (4)
# 3. python-config missing
#
# Top three most popular unanswered questions under 'Java' tag are:
# 1. ERRORCODE=-4461, SQLSTATE=42815 in DB2
# 2. Active Directory Authentication using Spring Security 3.2, Spring Ldap 2.0 and JavaConfig
# 3. apache http client org.apache.http.NoHttpResponseException: The target server failed to respond
#
# Please open .csv file for more detailed summary

# %%
import glob
import json
import requests
import operator
import time

bronze_list = {}
silver_list = {}
gold_list = {}
displayname_list = {}

for filename in glob.glob(r"users\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        
        try:
            for item in P["items"]:
                #print(item)
                bronze_list[item["user_id"]] = item["badge_counts"]["bronze"]
                silver_list[item["user_id"]] = item["badge_counts"]["silver"]
                gold_list[item["user_id"]] = item["badge_counts"]["gold"]
                displayname_list[item["user_id"]] = item["display_name"]
        except KeyError:
            print("")
        
bronze_list_sorted = sorted(bronze_list.items(), key=operator.itemgetter(1), reverse = True)
silver_list_sorted = sorted(silver_list.items(), key=operator.itemgetter(1), reverse = True)
gold_list_sorted = sorted(gold_list.items(), key=operator.itemgetter(1), reverse = True)

top_three_bronze = sorted(bronze_list, key=bronze_list.get, reverse=True)[0:3]
top_three_silver = sorted(silver_list, key=silver_list.get, reverse=True)[0:3]
top_three_gold = sorted(gold_list, key=gold_list.get, reverse=True)[0:3]

print(top_three_bronze)
print(top_three_silver)
print(top_three_gold)

i = 1
top_3_bronze = []
print("\n Top 3 users with maximum number of bronze badges are:")
for item in top_three_bronze:
    print("\t {pos}. {val}".format(pos=i, val = displayname_list[item]))
    top_3_bronze.append(displayname_list[item])
    i += 1
    
i = 1
top_3_silver = []
print("\n Top 3 users with maximum number of silver badges are:")
for item in top_three_silver:
    print("\t {pos}. {val}".format(pos=i, val = displayname_list[item]))
    top_3_silver.append(displayname_list[item])
    i += 1
    
i = 1
top_3_gold = []
print("\n Top 3 users with maximum number of gold badges are:")
for item in top_three_gold:
    print("\t {pos}. {val}".format(pos=i, val = displayname_list[item]))
    top_3_gold.append(displayname_list[item])
    i += 1
    
import pyexcel
pyexcel.save_as(array = bronze_list_sorted, dest_file_name = r'users\bronzeListSorted.csv')
pyexcel.save_as(array = silver_list_sorted, dest_file_name = r'users\silverListSorted.csv')
pyexcel.save_as(array = gold_list_sorted, dest_file_name = r'users\goldListSorted.csv')
pyexcel.save_as(array = top_3_bronze, dest_file_name = r'users\top_3_bronze.csv')
pyexcel.save_as(array = top_3_silver, dest_file_name = r'users\top_3_silver.csv')
pyexcel.save_as(array = top_3_gold, dest_file_name = r'users\top_3_gold.csv')
# Out:
# [22656, 157882, 29407]
# [22656, 29407, 157882]
# [22656, 4639, 4653]
#
#  Top 3 users with maximum number of bronze badges are:
# 	 1. Jon Skeet
# 	 2. BalusC
# 	 3. Darin Dimitrov
#
#  Top 3 users with maximum number of silver badges are:
# 	 1. Jon Skeet
# 	 2. Darin Dimitrov
# 	 3. BalusC
#
#  Top 3 users with maximum number of gold badges are:
# 	 1. Jon Skeet
# 	 2. Edward Tanguay
# 	 3. leora
